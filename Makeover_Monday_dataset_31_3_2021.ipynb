# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('UK Exports to the EU.xlsx')
df = df.drop('Unnamed: 5', axis =1)
df
# Out:
#           Month             Category   Exports (£m)   Imports (£m)  \
# 0    1997-01-01  Food & live animals            596           1075
# 1    1997-02-01  Food & live animals            626           1085
# 2    1997-03-01  Food & live animals            601           1088
# 3    1997-04-01  Food & live animals            610           1255
# 4    1997-05-01  Food & live animals            631           1106
# ...         ...                  ...            ...            ...
# 2885 2020-09-01    Unspecified goods              7             52
# 2886 2020-10-01    Unspecified goods             17             31
# 2887 2020-11-01    Unspecified goods             15             59
# 2888 2020-12-01    Unspecified goods              8             58
# 2889 2021-01-01    Unspecified goods            177             16
#
#       Balance (£m)
# 0             -479
# 1             -459
# 2             -487
# 3             -645
# 4             -475
# ...            ...
# ...

# %%
df['Category'].unique()
# Out:
# array(['Food & live animals', 'Beverages & tobacco', 'Crude materials',
#        'Fuels', 'Animal & vegetable oils & fats', 'Chemicals',
#        'Material manufactures', 'Machinery & transport equipment',
#        'Miscellaneous manufactures', 'Unspecified goods'], dtype=object)

# %%
df['Month'] = pd.to_datetime(df['Month'])

# %%
grouped = df.groupby('Month').agg({'Balance (£m)': np.sum})
grouped1 = grouped.reset_index()
grouped1
# Out:
#          Month  Balance (£m)
# 0   1997-01-01          1291
# 1   1997-02-01          1557
# 2   1997-03-01          1676
# 3   1997-04-01          1178
# 4   1997-05-01          1467
# ..         ...           ...
# 284 2020-09-01         -7481
# 285 2020-10-01         -6912
# 286 2020-11-01         -8517
# 287 2020-12-01         -8234
# 288 2021-01-01         -7903
#
# [289 rows x 2 columns]

# %%
plt.figure()
plt.bar(range(len(grouped1['Balance (£m)'])),grouped1['Balance (£m)'] )
plt.xticks([5,17,29,41,53,65,77,89,101,113,125,137,149,161,173,185,197,209,221,233,245,257,269,281], list(np.arange(1997,2021,1)), rotation = 60)
#plt.xlabel('YEARS')
plt.ylabel('Balance (£m)')
plt.title('UK Imports-Exports balance 1997-2020')
plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=True, labelbottom=True, labelsize = 'small')
for spine in plt.gca().spines.values():#we have to iterate thru all spines.values which are our four sides of the graph
    spine.set_visible(False,)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('Uk imports', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.3,
        metadata=None)

# %%
df
# Out:
#           Month             Category   Exports (£m)   Imports (£m)  \
# 0    1997-01-01  Food & live animals            596           1075
# 1    1997-02-01  Food & live animals            626           1085
# 2    1997-03-01  Food & live animals            601           1088
# 3    1997-04-01  Food & live animals            610           1255
# 4    1997-05-01  Food & live animals            631           1106
# ...         ...                  ...            ...            ...
# 2885 2020-09-01    Unspecified goods              7             52
# 2886 2020-10-01    Unspecified goods             17             31
# 2887 2020-11-01    Unspecified goods             15             59
# 2888 2020-12-01    Unspecified goods              8             58
# 2889 2021-01-01    Unspecified goods            177             16
#
#       Balance (£m)
# 0             -479
# 1             -459
# 2             -487
# 3             -645
# 4             -475
# ...            ...
# ...

# %%
beverage = df.where(df['Category'] == 'Beverages & tobacco').dropna()
beverage = beverage.set_index('Month')
plt.figure()
plt.plot(beverage[' Exports (£m)'], '-', label='Exports')
plt.plot(beverage[' Imports (£m)'], '-', label='Imports')
plt.legend(fontsize= 'small')
plt.ylabel('£m')
plt.title('Beverages & tobacco')

plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=True, labelbottom=True, labelsize = 'small')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('Beverages', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.3,
        metadata=None)

# %%
food = df.where(df['Category'] == 'Food & live animals').dropna()
food = food.set_index('Month')
plt.figure()
plt.plot(food[' Exports (£m)'], '-', label='Exports')
plt.plot(food[' Imports (£m)'], '-', label='Imports')
plt.legend(fontsize= 'small')
plt.ylabel('£m')
plt.title('Food & live animals')

plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=True, labelbottom=True, labelsize = 'small')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('Food', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.3,
        metadata=None)

# %%
crude = df.where(df['Category'] == 'Crude materials').dropna()
crude = crude.set_index('Month')
plt.figure()
plt.plot(crude[' Exports (£m)'], '-', label='Exports')
plt.plot(crude[' Imports (£m)'], '-', label='Imports')
plt.legend(fontsize= 'small')
plt.ylabel('£m')
plt.title('Crude materials')

plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=True, labelbottom=True, labelsize = 'small')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('Crude materials', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.3,
        metadata=None)

# %%
animals = df.where(df['Category'] == 'Animal & vegetable oils & fats').dropna()
animals = animals.set_index('Month')
plt.figure()
plt.plot(animals[' Exports (£m)'], '-', label='Exports')
plt.plot(animals[' Imports (£m)'], '-', label='Imports')
plt.legend(fontsize= 'small')
plt.ylabel('£m')
plt.title('animals & vegetable oils & fats')

plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=True, labelbottom=True, labelsize = 'small')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('Animals', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.3,
        metadata=None)

# %%
fuels = df.where(df['Category'] == 'Fuels').dropna()
fuels = fuels.set_index('Month')
plt.figure()
plt.plot(fuels[' Exports (£m)'], '-', label='Exports')
plt.plot(fuels[' Imports (£m)'], '-', label='Imports')
plt.legend(fontsize= 'small')
plt.ylabel('£m')
plt.title('Fuels')

plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=True, labelbottom=True, labelsize = 'small')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('Fuels', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.3,
        metadata=None)

# %%
chemicals = df.where(df['Category'] == 'Chemicals').dropna()
chemicals = chemicals.set_index('Month')
plt.figure()
plt.plot(chemicals[' Exports (£m)'], '-', label='Exports')
plt.plot(chemicals[' Imports (£m)'], '-', label='Imports')
plt.legend(fontsize= 'small')
plt.ylabel('£m')
plt.title('Chemicals')

plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=True, labelbottom=True, labelsize = 'small')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('Chemicals', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.3,
        metadata=None)

# %%
materials = df.where(df['Category'] == 'Material manufactures').dropna()
materials = materials.set_index('Month')
plt.figure()
plt.plot(materials[' Exports (£m)'], '-', label='Exports')
plt.plot(materials[' Imports (£m)'], '-', label='Imports')
plt.legend(fontsize= 'small')
plt.ylabel('£m')
plt.title('Materials')

plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=True, labelbottom=True, labelsize = 'small')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('Materials', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.3,
        metadata=None)

# %%
machinery = df.where(df['Category'] == 'Machinery & transport equipment').dropna()
machinery = machinery.set_index('Month')
plt.figure()
plt.plot(machinery[' Exports (£m)'], '-', label='Exports')
plt.plot(machinery[' Imports (£m)'], '-', label='Imports')
plt.legend(fontsize= 'small')
plt.ylabel('£m')
plt.title('Machinery & Transport equipment')

plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=True, labelbottom=True, labelsize = 'small')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('machinery', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.3,
        metadata=None)

# %%
miscellaneous = df.where(df['Category'] == 'Miscellaneous manufactures').dropna()
miscellaneous = miscellaneous.set_index('Month')
plt.figure()
plt.plot(miscellaneous[' Exports (£m)'], '-', label='Exports')
plt.plot(miscellaneous[' Imports (£m)'], '-', label='Imports')
plt.legend(fontsize= 'small')
plt.ylabel('£m')
plt.title('Miscellaneous manufactures')

plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=True, labelbottom=True, labelsize = 'small')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('miscellaneous', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.3,
        metadata=None)

# %%
unspecified = df.where(df['Category'] == 'Unspecified goods').dropna()
unspecified = unspecified.set_index('Month')
plt.figure()
plt.plot(unspecified[' Exports (£m)'], '-', label='Exports')
plt.plot(unspecified[' Imports (£m)'], '-', label='Imports')
plt.legend(fontsize= 'small')
plt.ylabel('£m')
plt.title('Unspecified goods')

plt.tick_params(top=False, bottom=False, left=False, right=False, labelleft=True, labelbottom=True, labelsize = 'small')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('Unspecified', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.3,
        metadata=None)
