# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Mount kenya.xlsx')
df
# Out:
#            County country  population  registered voters  Land area
# 0        Laikipia   Kenya      518560             246487       9508
# 1           Nyeri   Kenya      759164             456949       3325
# 2         Muranga   Kenya     1056640             587126       2523
# 3       Nyandarua   Kenya      638289             335634       3286
# 4   Tharaka Nithi   Kenya      393177             213154       2564
# 5          Nakuru   Kenya     2162202             949618       7505
# 6       Kirinyaga   Kenya      610411             349836       1478
# 7            Meru   Kenya     1545714             702480       7041
# 8            Embu   Kenya      608599             309468       2821
# 9          Kiambu   Kenya     2417735            1180920       2539
# 10    mount kenya   kenya    10710491            5331672      42590
# 11       the rest   kenya    36869509           14279751     538305

# %%
plt.figure()
plt.pie(df['population'][-2:], colors = ['#0080FF', 'darkred'], autopct = '%0.1f%%' ,labels = ['Mount Kenya\npopulation','Rest of the country' ],explode = [0.3,0], startangle=270,shadow = True, labeldistance = 1.1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.pie(df['registered voters'][-2:], colors = ['blue', 'orange'], autopct = '%0.1f%%' ,labels = ['Mount Kenya\nregistered voters','Rest of the country' ],explode = [0,0], startangle=270,shadow = False, labeldistance = 1.1)
circle = plt.Circle(xy = (0,0), radius = 0.7, facecolor = 'white')
plt.gca().add_artist(circle)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
'''plt.savefig('mt voters pie', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.1,
        metadata=None)'''
# Out:
# "plt.savefig('mt voters pie', dpi=None,\n        orientation='portrait', format=None,\n        transparent= True, bbox_inches=None, pad_inches=0.1,\n        metadata=None)"

# %%
plt.figure()
plt.pie(df['Land area'][-2:], colors = ['#bc2a71', '#182d48'], autopct = '%0.1f%%' ,labels = ['Mount Kenya\nland area','Rest of the country' ],explode = [0.3,0], startangle=270,shadow = True, labeldistance = 1.19,) #
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('mt land pie', dpi=None,
        orientation='portrait', format=None,
        transparent= True, bbox_inches=None, pad_inches=0.1,
        metadata=None)
