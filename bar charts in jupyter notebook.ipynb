# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# %matplotlib notebook

# %%
#we have set our datasets
xvals = np.arange(1,9)
xvals
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
#we plot our bar charts
plt.bar(xvals, range(len(xvals)),width=0.4, color='green',label='arrays')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xlabel('counties')
plt.ylabel('height')
plt.title('counties and height relationship')
plt.legend(title='legend')
plt.show()
